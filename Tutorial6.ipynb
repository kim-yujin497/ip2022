# %%
img = cv2.imread('noisy2.png',0)
blur = cv2.GaussianBlur(img,(5,5),0)

# find normalized_histogram, and its cumulative distribution function
hist = cv2.calcHist([blur],[0],None,[256],[0,256])
hist_norm = hist.ravel()/hist.max()
Q = hist_norm.cumsum()
bins = np.arange(256)
fn_min = np.inf
thresh = -1

for i in xrange(1,256):
    p1,p2 = np.hsplit(hist_norm,[i]) # probabilities
    q1,q2 = Q[i],Q[255]-Q[i] # cum sum of classes
    b1,b2 = np.hsplit(bins,[i]) # weights

# finding means and variances
m1,m2 = np.sum(p1*b1)/q1, np.sum(p2*b2)/q2
v1,v2 = np.sum(((b1-m1)**2)*p1)/q1,np.sum(((b2-m2)**2)*p2)/q2

# calculates the minimization function
fn = v1*q1 + v2*q2

if fn < fn_min:
    fn_min = fn
    thresh = i

# find otsu's threshold value with OpenCV function
ret, otsu = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
print thresh,ret
# Out:
#   File "<ipython-input-1-43a156892569>", line 30
#     print thresh,ret
#                ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(thresh,ret)?

# %%
import cv2
import numpy as np

img = cv2.imread('messi5.jpg')
res = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_CUBIC)
#OR
height, width = img.shape[:2]
res = cv2.resize(img,(2*width, 2*height), interpolation = cv2.INTER_CUBIC)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-72e54f2853f0> in <module>
#       3
#       4 img = cv2.imread('messi5.jpg')
# ----> 5 res = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_CUBIC)
#       6 #OR
#       7 height, width = img.shape[:2]
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
import cv2
import numpy as np

img = cv2.imread('messi5.jpg',0)
rows,cols = img.shape
M = np.float32([[1,0,100],[0,1,50]])
dst = cv2.warpAffine(img,M,(cols,rows))

cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-a9d52f990814> in <module>
#       3
#       4 img = cv2.imread('messi5.jpg',0)
# ----> 5 rows,cols = img.shape
#       6 M = np.float32([[1,0,100],[0,1,50]])
#       7 dst = cv2.warpAffine(img,M,(cols,rows))
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
img = cv2.imread('messi5.jpg',0)
rows,cols = img.shape
M = cv2.getRotationMatrix2D((cols/2,rows/2),90,1)
dst = cv2.warpAffine(img,M,(cols,rows))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-d85f5171d039> in <module>
#       1 img = cv2.imread('messi5.jpg',0)
# ----> 2 rows,cols = img.shape
#       3 M = cv2.getRotationMatrix2D((cols/2,rows/2),90,1)
#       4 dst = cv2.warpAffine(img,M,(cols,rows))
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
img = cv2.imread('drawing.png')
rows,cols,ch = img.shape
pts1 = np.float32([[50,50],[200,50],[50,200]])
pts2 = np.float32([[10,100],[200,50],[100,250]])
M = cv2.getAffineTransform(pts1,pts2)
dst = cv2.warpAffine(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-b25b862ae2f7> in <module>
#       1 img = cv2.imread('drawing.png')
# ----> 2 rows,cols,ch = img.shape
#       3 pts1 = np.float32([[50,50],[200,50],[50,200]])
#       4 pts2 = np.float32([[10,100],[200,50],[100,250]])
#       5 M = cv2.getAffineTransform(pts1,pts2)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
img = cv2.imread('sudokusmall.png')
rows,cols,ch = img.shape
pts1 = np.float32([[56,65],[368,52],[28,387],[389,390]])
pts2 = np.float32([[0,0],[300,0],[0,300],[300,300]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(300,300))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
