# %%
x = 34 - 23

# %%
y = "Hello"

# %%
z = 3.45

# %%
if z == 3.45 or y == "Hello":
    x = x + 1
    y = y + " World”"

# %%
print x
# Out:
#   File "<ipython-input-12-0b640320f694>", line 1
#     print x
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(x)?

# %%
print (x)
# Out:
# 12

# %%
print (y)
# Out:
# Hello World”
