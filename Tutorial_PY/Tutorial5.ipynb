# %% [markdown]
# # Control Flow

# %%
x = 3

# %%
while x < 5:
    print(x, "still in the loop")
    x = x + 1
# Out:
# 3 still in the loop
# 4 still in the loop

# %%
x = 6

# %%
while x < 5:
    print(x, "still in the loop")
